# %%
import sklearn

from sklearn.datasets import fetch_california_housing

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor

housing=fetch_california_housing()

x=housing.data

y=housing.target
 
print(x.shape)

poly = PolynomialFeatures()
x = poly.fit_transform(x)

print(x.shape)
x_train, x_test, y_train, y_test = train_test_split(

x,

 y,

test_size=0.2,

random_state=432

)



mod =LinearRegression()
GBR = HistGradientBoostingRegressor()
RFR = RandomForestRegressor()



for i in [mod,GBR,RFR] :
    
    i.fit(x_train,y_train)

    y_pred=i.predict(x_test)

    mse = mean_squared_error(y_test,y_pred)
    print(mse,i)
# Out:
# (20640, 8)
# (20640, 45)
# 0.44245885261238493 LinearRegression()
# 0.21281810730632492 HistGradientBoostingRegressor()
# 0.2541523726649011 RandomForestRegressor()

# %%
import sklearn

from sklearn.datasets import fetch_california_housing

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor

housing=fetch_california_housing()

x=housing.data

y=housing.target
 
print(x.shape)

poly = PolynomialFeatures()
x = poly.fit_transform(x)

print(x.shape)
x_train, x_test, y_train, y_test = train_test_split(

x,

 y,

test_size=0.2,

random_state=432

)



mod =LinearRegression()
GBR = HistGradientBoostingRegressor()
RFR = RandomForestRegressor()



for i in [mod,GBR,RFR] :
    
    i.fit(x_train,y_train)

    y_pred=i.predict(x_test)

    mse = mean_squared_error(y_test,y_pred)
    print(mse,i)

# %%
import sklearn 
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
housing = fetch_california_housing()
x =housing.data
y =housing.target
print(x.shape)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=230)
LG = LinearRegression()
LG.fit(x_train,y_train)
y_pred = LG.predict(x_test)
mse = mean_squared_error(y_test,y_pred)
print(mse)

GBR = HistGradientBoostingRegressor()
GBR.fit(x_train,y_train)
y_pred = GBR.predict(x_test)
mse = mean_squared_error(y_test,y_pred)
print(mse)

RFG = RandomForestRegressor()
RFG.fit(x_train,y_train)
y_pred = RFG.predict(x_test)
mse = mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# (20640, 8)
# 0.5195408036822202
# 0.21429741713775713
# 0.24622611245234752

# %%
from sklearn.datasets import load_breast_cancer

df= load_breast_cancer(as_frame=True).frame
df
from sklearn.datasets import make_blobs
x,y=make_blobs()
