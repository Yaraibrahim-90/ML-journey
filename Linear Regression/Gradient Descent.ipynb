# %%
import numpy as np
import pandas as pd 
data={'students_grades':[23,60,90],'students_attendice':[50,30,80]}
df=pd.DataFrame(data)
x=df['students_grades'].values
y_true=df['students_attendice'].values
theta0=0
theta1=1
alpha=0,1
  
y_pred=theta0+theta1*x
mse = np.mean(np.square(y_pred - y_true))
n = len(x)
gradient_theta1 = (2/n) * np.sum((y_pred - y_true) * x)
gradient_theta0 = (2/n) * np.sum(y_pred - y_true)
theta1 = theta1 - (alpha * gradient_theta1)
theta0 = theta0 - (alpha * gradient_theta0)
print(f"Laps {i+1}: theta1 = {theta1:.2f}, MSE = {mse:.2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 16
#      12 mse = np.mean(np.square(y_pred - y_true))
#      13 n = len(x)
#      14 gradient_theta1 = (2/n) * np.sum((y_pred - y_true) * x)
#      15 gradient_theta0 = (2/n) * np.sum(y_pred - y_true)
# ---> 16 theta1 = theta1 - (alpha * gradient_theta1)
#      17 theta0 = theta0 - (alpha * gradient_theta0)
#      18 print(f"Laps {i+1}: theta1 = {theta1:.2f}, MSE = {mse:.2f}")
#
# TypeError: can't multiply sequence by non-int of type 'numpy.float64'
