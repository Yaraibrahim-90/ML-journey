# %%
# %pip install numpy
import numpy as np 
import pandas as pd 
data = {'area': [100, 200, 300], 'actual price': [50000, 10000, 34000]}
df=pd.DataFrame(data)
x=df['area'].values
y_true=df['actual price'].values
theta0=0
theta1=4000
y_pred=theta0+theta1*x
error=y_true-y_pred
mse=np.mean(np.square(error))
print(f'التوقعات بوجود theta0:{y_pred}')
print(f'التوقعات بوجود theta1:{y_pred}')
# Out:
#   Cell In[1], line 1
#     import numpyas np
#                    ^
# SyntaxError: invalid syntax
